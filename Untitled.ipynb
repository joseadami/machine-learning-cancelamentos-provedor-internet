# %% [markdown]
# # Importando bibliotecas

# %%
import pandas as pd
import numpy as np
import seaborn
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.decomposition import PCA
from sklearn import metrics
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.csv')
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %% [markdown]
# # Identificando e somando valores nulos

# %%
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %% [markdown]
# # Removendo valores nulos

# %%
df = df.dropna()
df.isnull().sum()
# Out:
# customerID          0
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df['TotalCharges'] = pd.to_numeric(df.TotalCharges, errors='coerce')


df = df.copy()
df.loc[:,('gender', 'Partner', 'Dependents', 'PhoneService','MultipleLines','InternetService', 'OnlineSecurity','DeviceProtection',
'TechSupport','StreamingTV', 'OnlineBackup','StreamingMovies','PaperlessBilling', 'Contract', 'PaymentMethod', 'Churn')] = df.loc[:,['gender', 'Partner', 'Dependents', 'PhoneService','MultipleLines',
                                                                                                                                                               'InternetService', 'OnlineSecurity','DeviceProtection', 'TechSupport',
                                                                                                                                                               'StreamingTV', 'OnlineBackup','StreamingMovies','PaperlessBilling',
                                                                                                                                                               'Contract', 'PaymentMethod', 'Churn']].apply(lambda x: pd.factorize(x)[0])
df
# Out:
#       customerID  gender  SeniorCitizen  Partner  Dependents  tenure  \
# 0     7590-VHVEG       0              0        0           0       1
# 1     5575-GNVDE       1              0        1           0      34
# 2     3668-QPYBK       1              0        1           0       2
# 3     7795-CFOCW       1              0        1           0      45
# 4     9237-HQITU       0              0        1           0       2
# ...          ...     ...            ...      ...         ...     ...
# 7038  6840-RESVB       1              0        0           1      24
# 7039  2234-XADUH       0              0        0           1      72
# 7040  4801-JZAZL       0              0        0           1      11
# 7041  8361-LTMKD       1              1        0           0       4
# 7042  3186-AJIEK       1              0        1           0      66
#
#       PhoneService  MultipleLines  InternetService  OnlineSecurity  ...  \
# ...

# %%
df = df.drop(columns=['customerID','gender', 'tenure', 'Partner', 'Dependents', 'PhoneService','MultipleLines', 
                      'OnlineBackup', 'OnlineBackup','StreamingMovies','PaperlessBilling','PaymentMethod', 
                      'MonthlyCharges', 'TotalCharges', 'SeniorCitizen'])

# %%
df = df.columns.drop('Churn')
scaler = StandardScaler()
X = scaler.fit_transform(df)
X
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-556702f098fa> in <module>
#       1 df = df.columns.drop('Churn')
#       2 scaler = StandardScaler()
# ----> 3 X = scaler.fit_transform(df)
#       4 X
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/base.py in fit_transform(self, X, y, **fit_params)
#     697         if y is None:
#     698             # fit method of arity 1 (unsupervised transformation)
# --> 699             return self.fit(X, **fit_params).transform(X)
#     700         else:
#     701             # fit method of arity 2 (supervised transformation)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/preprocessing/_data.py in fit(self, X, y, sample_weight)
#     728         # Reset internal state before fitting
#     729         self._reset()
# --> 730         return self.partial_fit(X, y, sample_weight)
#     731
# ...

# %%
# atributos = df.columns.drop('Churn')
# resultados = ['Churn']



# X = df[atributos]
# Y = df[resultados]

# %%
plt.figure(figsize=(14, 10))
sns.heatmap(X.corr(), cmap='YlGnBu', annot=True, fmt='.2f', vmin=0);
X

# %% [markdown]
# # Removendo colunas que não iremos utilizar

# %%
df = df.drop(columns=['customerID','gender', 'Partner', 'Dependents', 'PhoneService','MultipleLines', 
                      'OnlineBackup', 'OnlineBackup','StreamingMovies','PaperlessBilling','PaymentMethod', 
                      'MonthlyCharges', 'TotalCharges'])
df

# %% [markdown]
# # Separando atribuitos para X e resultados para Y

# %% [markdown]
# # Dados treino e teste

# %%
X_treino, X_teste, Y_treino, Y_teste = train_test_split(X, Y, test_size = 0.25, random_state = 40)

# %%
print("{0:0.2f}% nos dados de treino".format((len(X_treino)/len(df.index)) * 100))
print("{0:0.2f}% nos dados de teste".format((len(X_teste)/len(df.index)) * 100))

# %%
modelo_v1 = GaussianNB()

# %%
modelo_v1.fit(X_treino, Y_treino.ravel())

# %%
nb_predict_test = modelo_v1.predict(X_teste)

# %%
print('X_teste ', X_teste.shape)
print('X_treino ', X_treino.shape)
print('Y_teste ', Y_teste.shape)
print('Y_treino ', Y_treino.shape)

# %%
Y_treino.shape

# %%
print("Acurácia: {0:.4f}".format(metrics.accuracy_score(Y_teste, nb_predict_test)))

# %%
modelo_v2 = RandomForestClassifier()

# %%
modelo_v2.fit(X_treino, Y_treino.ravel())

# %%
nb_predict_test2 = modelo_v2.predict(X_teste)

# %%
print("Acurácia: {0:.4f}".format(metrics.accuracy_score(Y_teste, nb_predict_test2)))

# %%
modelo_v3 = DecisionTreeClassifier()
modelo_v3.fit(X_treino, Y_treino.ravel())
nb_predict_test3 = modelo_v3.predict(X_teste)
print("Acurácia: {0:.4f}".format(metrics.accuracy_score(Y_teste, nb_predict_test3)))
